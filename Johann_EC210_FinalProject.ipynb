# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import sqlite3 as sql  #*********************The new import**********************
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
house = pd.DataFrame()
house = pd.read_csv('HPI_master.csv')
house
# Out:
#              hpi_type     hpi_flavor  frequency                   level  \
# 0         traditional  purchase-only    monthly  USA or Census Division
# 1         traditional  purchase-only    monthly  USA or Census Division
# 2         traditional  purchase-only    monthly  USA or Census Division
# 3         traditional  purchase-only    monthly  USA or Census Division
# 4         traditional  purchase-only    monthly  USA or Census Division
# ...               ...            ...        ...                     ...
# 114726  developmental  purchase-only  quarterly             Puerto Rico
# 114727  developmental  purchase-only  quarterly             Puerto Rico
# 114728  developmental  purchase-only  quarterly             Puerto Rico
# 114729  developmental  purchase-only  quarterly             Puerto Rico
# 114730  developmental  purchase-only  quarterly             Puerto Rico
#
#                          place_name place_id    yr  period  index_nsa  \
# ...

# %%
nsa_avg = house['index_nsa'].mean()
nsa_avg
# Out:
# 164.17675170616644

# %% [raw]
# index_sum1=house['yr']['index_nsa']
# index_sum1=house[index_sum1]

# %%
house_year = house.sort_values('yr',ascending=False)
house_year
# Out:
#           hpi_type        hpi_flavor  frequency                   level  \
# 3609   traditional     purchase-only    monthly  USA or Census Division
# 2887   traditional     purchase-only    monthly  USA or Census Division
# 1443   traditional     purchase-only    monthly  USA or Census Division
# 2526   traditional     purchase-only    monthly  USA or Census Division
# 3248   traditional     purchase-only    monthly  USA or Census Division
# ...            ...               ...        ...                     ...
# 71509  traditional  all-transactions  quarterly                   State
# 71508  traditional  all-transactions  quarterly                   State
# 71507  traditional  all-transactions  quarterly                   State
# 71326  traditional  all-transactions  quarterly                   State
# 52890  traditional  all-transactions  quarterly                     MSA
#
#                                place_name place_id    yr  period  index_nsa  \
# ...

# %%
plt.plot(house['yr'],house['index_nsa'])
plt.title('Housing Index 1975-2021')
plt.xlabel('Year')
plt.ylabel('Index Value')
# Out:
# Text(0, 0.5, 'Index Value')

# %%
construct=pd.DataFrame()
construct=pd.read_csv('co_cust.csv')
construct
# Out:
#           New Privately Owned Housing Units Completed Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                         Annual Data        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3   (Components may not add to total because of ro...        NaN        NaN
# 4                                                 NaN        NaN        NaN
# ..                                                ...        ...        ...
# 61                                                NaN        NaN        NaN
# 62                                  NA Not available.        NaN        NaN
# 63                                                NaN        NaN        NaN
# 64  Note: Single-family estimates prior to 1999 in...        NaN        NaN
# 65  structures completed in permit-issuing areas w...        NaN        NaN
#
# ...

# %%
price_uc_cost=pd.DataFrame()
price_uc_cost=pd.read_csv('price_uc_cust.csv')
price_uc_cost
# Out:
#        Date Unnamed: 1  Laspeyres (Fixed)  Fisher (Deflator)
# 0    Jan-64        NaN               12.2               11.8
# 1    Feb-64        NaN               12.1               11.7
# 2    Mar-64        NaN               12.0               11.6
# 3    Apr-64        NaN               12.2               11.8
# 4    May-64        NaN               12.3               12.0
# ..      ...        ...                ...                ...
# 682  Nov-20        NaN              142.2              143.3
# 683  Dec-20        NaN              143.2              144.4
# 684  Jan-21          r              145.0              146.2
# 685  Feb-21          r              146.2              147.5
# 686  Mar-21          p              147.0              148.6
#
# [687 rows x 4 columns]

# %%
price_cost_select_yr=price_uc_cost['Date'].tail(100)
price_cost_select_yr
# Out:
# 587    Dec-12
# 588    Jan-13
# 589    Feb-13
# 590    Mar-13
# 591    Apr-13
#         ...
# 682    Nov-20
# 683    Dec-20
# 684    Jan-21
# 685    Feb-21
# 686    Mar-21
# Name: Date, Length: 100, dtype: object

# %%
plt.plot(price_uc_cost['Date'],price_uc_cost['Fisher (Deflator)'])
plt.title('Housing Index 1968-2021')
plt.xlabel('Year')
plt.ylabel('Deflated Price')
# Out:
# Text(0, 0.5, 'Deflated Price')

# %%
nsa_yr_unique=house['yr'].unique()
nsa_yr_unique
# Out:
# array([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 1986, 1987,
#        1988, 1989, 1990, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1975], dtype=int64)

# %%
rec_nsa = house['yr'] = ('2008','2009','2010','2011')
rec_nsa = house[rec_nsa]
rec_nsa
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5c1296631333> in <module>
# ----> 1 rec_nsa = house['yr'] = ('2008','2009','2010','2011')
#       2 rec_nsa = house[rec_nsa]
#       3 rec_nsa
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
# ...

# %%
price_sold_cust =pd.DataFrame()
price_sold_cust=pd.read_csv('cust_altered.csv')
price_sold_cust
# Out:
#     Year  Annual  First Quarter  Second Quarter  Third Quarter  \
# 0   1963    11.7           11.7            11.6           11.5
# 1   1964    11.8           11.5            11.6           11.7
# 2   1965    12.0           11.9            11.9           11.9
# 3   1966    12.5           12.1            12.6           12.4
# 4   1967    12.8           12.8            12.7           12.7
# 5   1968    13.5           13.3            13.4           13.4
# 6   1969    14.5           14.3            14.5           14.6
# 7   1970    14.9           14.7            15.2           14.8
# 8   1971    15.8           15.3            15.7           15.9
# 9   1972    16.8           16.4            16.5           16.8
# 10  1973    18.2           17.5            18.1           18.7
# 11  1974    19.9           19.4            19.8           20.3
# 12  1975    22.1           21.6            21.9           22.1
# 13  1976    24.0           23.1            23.8           24.5
# ...

# %%
overylay = price_sold_cust.groupby("Year", as_index = False).count()

plt.plot(price_sold_cust["Year"],price_sold_cust["Northeast"])
overylay = price_sold_cust.groupby("Year", as_index = False).count()

plt.plot(price_sold_cust["Year"],price_sold_cust["Midwest"])
overylay = price_sold_cust.groupby("Year", as_index = False).count()

plt.plot(price_sold_cust["Year"],price_sold_cust["South"])
overylay = price_sold_cust.groupby("Year", as_index = False).count()

plt.plot(price_sold_cust["Year"],price_sold_cust["West"])

plt.xlabel("Year")
plt.ylabel("Region Prices")
plt.title("US Housing Price by Region & Year")
plt.legend(["Northeast", "Midwest", "South", "West",],loc="upper left", bbox_to_anchor=(1.0, 1.0))
fig, ax = plt.subplots()
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.bar(price_sold_cust["Year"],price_sold_cust["Northeast"])
bar_width=1

plt.bar(price_sold_cust["Year"],price_sold_cust["Midwest"])
bar_width=1

plt.bar(price_sold_cust["Year"],price_sold_cust["South"])
bar_width=1

plt.bar(price_sold_cust["Year"],price_sold_cust["West"])
bar_width=1
plt.xlabel("Year")
plt.ylabel("Region Prices")
plt.title("US Housing Price by Region & Year")
plt.legend(["Northeast", "Midwest", "South", "West",],loc="upper left", bbox_to_anchor=(1.0, 1.0))
fig, ax = plt.subplots()
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
cust_two=pd.DataFrame()
cust_two=pd.read_csv('cust_altered_two.csv')
cust_two
# Out:
#     Year  Home Price  Unnamed: 2  Price Index  \
# 0   1963        19300        (X)         11.7
# 1   1964        20500      6.20%         11.8
# 2   1965        21500      4.90%         12.0
# 3   1966        23300      8.40%         12.5
# 4   1967        24600      5.60%         12.8
# 5   1968        26600      8.10%         13.5
# 6   1969        27900      4.90%         14.5
# 7   1970        26600     -4.70%         14.9
# 8   1971        28300      6.40%         15.8
# 9   1972        30500      7.80%         16.8
# 10  1973        35500     16.40%         18.2
# 11  1974        38900      9.60%         19.9
# 12  1975        42600      9.50%         22.1
# 13  1976        48000     12.70%         24.0
# 14  1977        54200     12.90%         27.0
# 15  1978        62500     15.30%         30.9
# 16  1979        71800     14.90%         35.3
# 17  1980        76400      6.40%         38.9
# 18  1981        83000      8.60%         42.0
# ...

# %%
corr_cust = np.corrcoef(cust_altered_two['Year'],cust_altered_two['Price Index'])
corr_cust
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-56b75517cfd6> in <module>
# ----> 1 corr_cust = np.corrcoef(cust_altered_two['Price Index'],cust_altered_two['Home Price'])
#       2 corr_cust
#
# NameError: name 'cust_altered_two' is not defined

# %%
plt.plot(cust_two['Year'],cust_two['Price Index'])
plt.xlabel('Year')
plt.ylabel('Price Index')
plt.title('Home Construction Cost Index Through Time')
# Out:
# Text(0.5, 1.0, 'Home Construction Cost Index Through Time')

# %%
permits_two=pd.DataFrame()
permits_two=pd.read_csv('permitsbyregannual_two.csv')
permits_two
# Out:
#          Universe    Year   Total   1 unit  2 units  3 to 4 \nunits  \
# 0             NaN     NaN  1769.0  1,077.6     50.4            58.0
# 1   1984 Universe  1986.0  1535.0  1,024.4     40.8            48.5
# 2             NaN  1987.0  1456.0    993.8     35.0            40.7
# 3             NaN  1988.0  1338.0    931.7     31.7            35.3
# 4             NaN  1989.0  1111.0    793.9     26.7            27.6
# 5             NaN  1990.0   949.0    753.5     22.0            21.1
# 6             NaN  1991.0  1095.0    910.7     23.3            22.5
# 7             NaN  1992.0  1199.0    986.5     26.7            25.6
# 8             NaN  1993.0  1372.0  1,068.5     31.4            30.8
# 9   1994 Universe  1994.0  1333.0    997.3     32.2            31.5
# 10            NaN  1995.0  1426.0  1,069.5     33.6            32.2
# 11            NaN  1996.0  1441.0  1,062.4     34.9            33.6
# 12            NaN  1997.0  1612.0  1,187.6     33.2            36.0
# ...

# %%
plt.plot(permits_two['Year'],permits_two['Total'])
plt.xlabel('Year')
plt.ylabel('Total Permits/yr')
plt.title('Building Permits Through Time')
# Out:
# Text(0.5, 1.0, 'Building Permits Through Time')

# %%
import numpy as np
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
from datetime import datetime
from urllib.request import urlopen
import json
import plotly.express as px
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson
-counties-fips.json') as response:
counties = json.load(response)
# Out:
#   File "<ipython-input-42-bc08650b5707>", line 12
#     with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson
#                                                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
permits_price=pd.DataFrame()
permits_price=pd.read_csv('permits_price.csv')
permits_price
# Out:
#          Universe    Year   Total   1 unit  2 units  3 to 4 \nunits  \
# 0             NaN     NaN  1769.0  1,077.6     50.4            58.0
# 1   1984 Universe  1986.0  1535.0  1,024.4     40.8            48.5
# 2             NaN  1987.0  1456.0    993.8     35.0            40.7
# 3             NaN  1988.0  1338.0    931.7     31.7            35.3
# 4             NaN  1989.0  1111.0    793.9     26.7            27.6
# 5             NaN  1990.0   949.0    753.5     22.0            21.1
# 6             NaN  1991.0  1095.0    910.7     23.3            22.5
# 7             NaN  1992.0  1199.0    986.5     26.7            25.6
# 8             NaN  1993.0  1372.0  1,068.5     31.4            30.8
# 9   1994 Universe  1994.0  1333.0    997.3     32.2            31.5
# 10            NaN  1995.0  1426.0  1,069.5     33.6            32.2
# 11            NaN  1996.0  1441.0  1,062.4     34.9            33.6
# 12            NaN  1997.0  1612.0  1,187.6     33.2            36.0
# ...

# %%
corr_permit_price=np.corrcoef(permits_price['Total'],permits_price['Price Index'])
corr_permit_price
# Out:
# array([[nan, nan],
#        [nan,  1.]])

# %%
home_val = pd.DataFrame()
home_val=pd.read_csv('homevalue_alter.csv')
home_val
# Out:
#          Universe    Year  United States Total    1 unit  2 units  \
# 0             NaN     NaN                  NaN       NaN      NaN
# 1   1984 Universe  1986.0              98005.0   73695.0   2097.0
# 2             NaN  1987.0              98346.0   78198.0   1800.0
# 3             NaN  1988.0             101625.0   82815.0   1728.0
# 4             NaN  1989.0             100698.0   83002.0   1641.0
# 5             NaN  1990.0              86522.0   72310.0   1405.0
# 6             NaN  1991.0              78772.0   69723.0   1170.0
# 7             NaN  1992.0              95539.0   87071.0   1272.0
# 8             NaN  1993.0             106801.0   97119.0   1479.0
# 9   1994 Universe  1994.0             123278.0  109294.0   1813.0
# 10            NaN  1995.0             120811.0  104739.0   1910.0
# 11            NaN  1996.0             134176.0  116535.0   2069.0
# 12            NaN  1997.0             141004.0  121194.0   2304.0
# ...

# %%
plt.plot(home_val['Year'],home_val['United States Total'])
plt.title('Home Values Through Time')
plt.xlabel('Years')
plt.ylabel('Home Values')
# Out:
# Text(0, 0.5, 'Home Values')

# %%
max_val=home_val['United States Total'].max()
max_val
# Out:
# 329254.0

# %%
max_year= max_val['Year']
max_year
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-706cb80e795f> in <module>
# ----> 1 max_year= max_val['Year']
#       2 max_year
#
# TypeError: 'float' object is not subscriptable

# %%
curr_val= home_val['Year'].head(1)
curr_val
# Out:
# 0   NaN
# Name: Year, dtype: float64

# %%
plt.scatter(home_val['Year'],home_val['United States Total'])
plt.title('Home Values Through Time')
plt.xlabel('Years')
plt.ylabel('Home Values')
# Out:
# Text(0, 0.5, 'Home Values')

# %%
home_mean=home_val['United States Total'].mean()
home_mean
# Out:
# 175799.8

# %%
plt.bar(home_val['United States Total'],home_val['Year'])
plt.title('Home Values Through Time')
plt.xlabel('Years')
plt.ylabel('Home Values')
# Out:
# Text(0, 0.5, 'Home Values')

# %%
# standard deviation = 73,783
#mean  = 175799.8

# %%
total=pd.DataFrame()
total=home_val['United States Total']
total
# Out:
# 0          NaN
# 1      98005.0
# 2      98346.0
# 3     101625.0
# 4     100698.0
# 5      86522.0
# 6      78772.0
# 7      95539.0
# 8     106801.0
# 9     123278.0
# 10    120811.0
# 11    134176.0
# 12    141004.0
# 13    165266.0
# 14    181246.0
# 15    185744.0
# 16    196248.0
# 17    219189.0
# 18    249693.0
# 19    292414.0
# 20    329254.0
# 21    291314.0
# 22    225237.0
# 23    141633.0
# 24     95410.0
# 25    101943.0
# 26    105269.0
# 27    140425.0
# 28    177656.0
# 29    194350.0
# 30    223611.0
# 31    237102.0
# 32    258505.0
# 33    271120.0
# 34    280534.0
# 35    304253.0
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53         NaN
# Name: United States Total, dtype: float64

# %%
no_out=total <=234135
total[no_out]
# Out:
# 1      98005.0
# 2      98346.0
# 3     101625.0
# 4     100698.0
# 5      86522.0
# 6      78772.0
# 7      95539.0
# 8     106801.0
# 9     123278.0
# 10    120811.0
# 11    134176.0
# 12    141004.0
# 13    165266.0
# 14    181246.0
# 15    185744.0
# 16    196248.0
# 17    219189.0
# 22    225237.0
# 23    141633.0
# 24     95410.0
# 25    101943.0
# 26    105269.0
# 27    140425.0
# 28    177656.0
# 29    194350.0
# 30    223611.0
# Name: United States Total, dtype: float64

# %%
# median = 153450

# %%
overylay = home_val.groupby("Year", as_index = False).count()

plt.plot(home_val["Year"],home_val["Northeast Total"])
overylay = home_val.groupby("Year", as_index = False).count()

plt.plot(home_val["Year"],home_val["Midwest Total"])
overylay = home_val.groupby("Year", as_index = False).count()

plt.plot(home_val["Year"],home_val["South"])
overylay = home_val.groupby("Year", as_index = False).count()

plt.plot(home_val["Year"],home_val["West Total"])

plt.xlabel("Year")
plt.ylabel("Region Values")
plt.title("US Housing Values by Region & Year")
plt.legend(["Northeast", "Midwest", "South", "West",],loc="upper left", bbox_to_anchor=(1.0, 1.0))
fig, ax = plt.subplots()
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
